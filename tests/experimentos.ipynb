# %%
from src.database.db_utils import DatabaseConnection
import pandas as pd

db = DatabaseConnection()
df = db.execute_query("SELECT DISTINCT nivel_1 FROM fc")

print(df)
# Out:
#                          nivel_1
# 0    7.2 Saídas não operacionais
# 1               6. Investimentos
# 2  7.1 Entradas não operacionais
# 3              5. Despesas Fixas
# 4            4. Custos Variáveis
# 5  7.1 Entradas Não Operacionais
# 6                              0
# 7    7.2 Saídas Não Operacionais
# 8                    3. Receitas

# %%
print(df.to_string())
# Out:
#                          nivel_1
# 0    7.2 Saídas não operacionais
# 1               6. Investimentos
# 2  7.1 Entradas não operacionais
# 3              5. Despesas Fixas
# 4            4. Custos Variáveis
# 5  7.1 Entradas Não Operacionais
# 6                              0
# 7    7.2 Saídas Não Operacionais
# 8                    3. Receitas
